# %% [markdown]
# * Expressions 연산자
#
#   ![image.png](attachment:b286f1ee-32e7-43ee-b604-d7b9e85fbd21.png)

# %%
xx = 2
xx= xx +2
print(xx)

yy =440 *12
print(yy)

zz = yy / 1000
print(zz)

jj = 23
kk = jj % 5
print(kk)

print(4 ** 3)
# Out:
# 4
# 5280
# 5.28
# 3
# 64

# %%
#연산되는 순서
# 괄호 - 거듭제곱 -곱/나누기 - 덧/뺄 
x = 1 + 2 ** 3 / 4 * 5
print(x)
# Out:
# 11.0

# %%
# type

ddd = 1 + 4
print(ddd)

eee = 'hello' + 'there'
print(eee)
# Out:
# 5
# hellothere

# %%
# type matters
eee = 'hello' + 'there' #class 'str'
eee = eee + 1 # class 'int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # type matters
#       2 eee = 'hello' + 'there' #class 'str'
# ----> 3 eee = eee + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type Conversions
## 변환시키고 싶은 타입 형식으로 감싸주면 타입이 바뀌게 됩니다.
print(float(99) + 100)
     
i = 42
type( i ) # int 타입
f = float( i ) # float 타입으로 변환
print( f ) # 42.0으로 출력
type( f ) # float 타입
# Out:
# 199.0
# 42.0
# float

# %%
# integer division (나눗셈)
print(10/2)
print(9/2)
print(99/100)
print(10.0/2.0)
print(99.0/100.0)
# Out:
# 5.0
# 4.5
# 0.99
# 5.0
# 0.99

# %%
#String coversions
sval = '123'
type(sval) # class'str'
# print(sval + 1) <- TypeError: can only concatenate str (not "int") to str

ival = int(sval)
type(ival) # class 'int'
print(ival +1)

nsv = 'hello friend'
# niv = int(nsv) # ValueError: invalid literal for int() with base 10: 'hello friend' = 숫자를 입력해야 했는데 문자가 입력됨
# Out:
# 124

# %%
# User input
nam = input('who are you?')
print('Welcome', nam)
# Out:
# who are you? Eunma
# Welcome Eunma

# %%
# Converting user Input
inp = input('Asian floor?')
usf = int(inp) - 1
print('US floor' , usf)
# Out:
# Asian floor? 65
# US floor 64
